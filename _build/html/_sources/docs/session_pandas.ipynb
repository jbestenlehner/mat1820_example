# %% [markdown]
# # Tutorial: Reading in and writing out data with Pandas

# %% [markdown]
# ## Read in structure from file
#
# To read in the file structure in a `DataFrame` you can use the `pd.read_csv()` function from Pandas.
#
# Note: as it is a text file separated by whitespaces we need to set the parameter `delim_whitespace = True`.
#
# The first line of the header/comment describes the data file ('test file') and we can ignore it. The second row provides us information about the columns, which would be sensible labels for the pandas `DataFrame`. So we only skip the first row.

# %%
import pandas as pd

df_xy = pd.read_csv('test.txt', delim_whitespace = True, skiprows=1) # reads data into Pandas dataframe.
print(df_xy)          # prints content of dataframe
print(df_xy.columns)  # shows column labels
print(df_xy.dtypes)   # prints data type for each column

plt.plot(df_xy['x'], df_xy['y'],'r-') # plot data
plt.plot(df_xy.x, df_xy.y,'b--')      # if labels do not contain spaces or special signs like '\', '|', '/', '#', ..., you can access columns with '.<column label>.
plt.show()
plt.close()

# %% [markdown]
# ## Task 1
# Download the file 'task1.csv' from blackboard and place it into your current workspace on Colab. The file contains the voltage-current measurements of two samples. Column one is the voltage. Columns 2 and 3 are the current generated in sample 1 and 2 respectively.
# - Look at the file and identify
# - how many text headings it has, and the deliminator that separates the values.
# - Use these to read in the file with `np.loadtxt()`
# - Separate the columns into separated arrays.
# - Plot sample 1 and sample 2 on the same graph.
# - Label the axis including units.

# %% [markdown]
# Now use `pd.read_csv()` to read the file into a Pandas data file and plot the data as above.
#
# Hint: The second row contains the Units of each column. To use the first row as column labels and skip the second row set parameter `skiprows = [1]`. Note: Python starts counting from 0.
