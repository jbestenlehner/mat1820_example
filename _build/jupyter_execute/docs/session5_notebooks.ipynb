# %% [markdown]
# # Tutorial: Conditions and Loops
#
# ## Logic and flow
# This live script will teach you how to test variables if they meet certain criteria. It will also show how you can loop through and repeat tasks.
#
# Scripts and programs can have three main types of flow.
#
# ![logic_loop](https://raw.githubusercontent.com/jbestenlehner/mat1820_example/refs/heads/main/pictures/logic_loop.png)
#
# - The first is a sequence, a set of commands that are followed one after another. This is what we have been doing so far.
# - The second is a choice, where you ask the code "IF a variable is equal to this, do A, else do B "
# - The third is repetition, where we ask the code to loop over things for a set number or until a choice is met.
#
# ## Logical statements
# There are a few conditional logic statements that you can use to test values and variables. Many you have seen in maths.
#
# ### Relational Operators
#
# These work on boolean answers, that of `True` or `False`.
#
# - Note that Using an `=` with two variables means you assign one of them as the value of the other. Using `==` tests if the two variables are equivalent.
# - Below values are assigned to a variable, compared to each other and the answers are displayed with `print()` to the screen.
# - You can invert your logic using a `not` or symbol `~`.
# - You can test two things using `and` or `&` (logical `and`, both tests need to be true), or `or` or `|` (logical `or`, one of two tests needs to be true).
#
# A more details are given on the overview page of this [session](#session5).

# %%
x, y, z = 5, 4, 5  # assign values to variables x, y and z
print(x > y)       # True - x is bigger than y is true
print(x < y)       # False - x is not bigger than y, false

print(x == y)      # False - x is not equivalent to y
print(x == z)      # True - x is  equivalent to z

print(x < z)       # False - x is not smaller than z
print(x <= z)      # True - x is equal or smaller than z 

print(x != y)      # True - x is NOT equal to y
print(not(z < y))  # True - inverts answer as z is NOT smaller than y

print((x == z) and (y < x)) # True - x is equivalent to z AND y is smaller than x
print((x == z) & (x < y))   # False - x is equivalent to z but y is NOT smaller than x
print((x == z) or (x < y))  # True - x is equivalent to z, y is NOT smaller than x but only one needs to be true
print((x == z) ^ (x > y))   # False - x is equivalent to z, y is smaller than x, but either one or the other needs to be true (exclusive or, XOR)

# %% [markdown]
# ### Relational Operators with arrays
# Only `True` values will be selected when used with a vector (1D array) or matrix (multi-dimensional array):

# %%
import numpy as np

a = np.arange(10) # creates array
b = a <= 2        # creates array of True and False
print(b)          # prints boolean array
print(a[b])       # prints only True values of a

# %% [markdown]
# ## Task 1
# Create a vector B that goes from 0 to 10 in steps of 1. Using a relational operator, find the values of the vector that are above 5 and print them to the screen.
#
# - Set up the vector B
# - Generate a true and false vector for values above 5.
# - Create a third vector of only the true values and use `print()` to print the values to the screen.

# %% [markdown]
# ## Conditional logic
# Conditional logic also works with boolean answers and can be used to control the decision making using the relational operators. We can do this through conditional expressions such as `if`, `elif` (else if) and `else` statements.
#
# - Note: In python any value entered is a string and needs to be converted to a numerical value with `int()` or `float()`

# %%
# ask the user to enter a value
x = int(input('Enter the percentage mark you want for this course: ')) # the string needs to be converted into a numerical value so that it can be compared to a numerical value.
if (x == 100):
    print("Aim high!\n")
elif (x >= 70):
    print(f'{x:.0f} is a first class honors')
elif (x >= 60):
    print(f'A {x:.0f} mark is a 2:1')
elif (x >= 50):
    print(f'A {x:.0f} mark is a 2:2')
elif (x >= 40):
    print(f'You can do better than that') 
elif (x > 0):
    print(f'Too low')
else: 
    print(f'That is not a valid score')

# %% [markdown]
# This code sorts the data you have entered into one of the answers above and then ends. It starts with `if`, if `True` prints and then terminates. If not `True` (`False`), moves to see if the `elif` is `True`, and so on. Note also the `else` section at the end which catches all the other options.
# You can have as many `elif` as you want, but it needs to start with an `if`. The `else` statement is also optional.
#
# ## Protection in algorithms using conditional logic
# You can use an `if` statement to end a program early if the user inputs something incorrectly, for example a negative number when your operation is calculating a square root. To do the code test in one line that both variables are correct using the `or` (`|`) logic operator. If either is wrong the code will return and exit.

# %%
a = float(input('enter a positive number: '))
b = float(input('enter a negative number: '))

print('a = {:.1f} and b = {:.1f}'.format(a,b))

if (a < 0) or (b > 0):
    print('Not correct')
else: 
    print('answer is {:.2f}\n'.format(b*a**0.5))

# %% [markdown]
# ## Using If blocks as option flow
# You can use inputs to direct the flow of your algorithm. Here we ask the user to enter a value which specifies what the program does next.

# %%
import numpy as np

x = int(input('Enter a value:\n1 finds the maximum \n2 finds the minimum\n3 finds the average\n'))
y = np.array([6.85,1.34,9.55,3.53,6.53,7.54])
if(x==1):
    print('{:.2f}'.format(y.max()))
elif(x==2):
    print('{:.2f}'.format(y.min()))
elif(x==3):
    print('{:.2f}'.format(y.mean()))
else:
    print('{:.0f} is not an option'.format(x))

# %% [markdown]
# ## Task 2
# Write an algorithm that:
# - Asks the user to enter a value and assign this to a variable called POS.
# - Test to see if the variable is positive or not.
# - If it is negative, end the algorithm early with a message to the user.
# - If true, calculate the value $\ln \sqrt{\mathrm{POS}}$ and print to the screen.

# %% [markdown]
# ## Task 3
#
# Write a guessing game algorithm. it should include:
# - The computer picking a random integer number in a pre-defined range.
# - Asking you to guess it.
# - If you guess correctly it displays to the screen “well done”
# - Guess it wrong and it says “better luck next time”.

# %% [markdown]
# ## Conditional logic and strings
# You can use `if` statements with strings to direct a program to run certain options. To do this, you need to compare the input to a string.

# %%
x = input('Type y to get a nice message: ')
if x == 'y':
    print('You are looking good today')
else: 
    print('You are not looking too good')

# %% [markdown]
# ## Task 4
#
# Write an algorithm that:
# - Asks the user to enter a value.
# - Asks the user if the value entered is degrees celsius or degrees fahrenheit.
# - If you enter C it converts and prints the value in fahrenheit to the screen.
# - If you enter F it converts and prints the value in celsius to the screen.
# - Make sure it only calculates values above absolute zero.
# - The conversion is (X**°F** − 32) × 5/9 = Y**°C**

# %% [markdown]
# ## Task 5
# Write a function the calculates the geometric factor for a finite plate using the equations below for either a through thickness centre crack ($Y_C$) or a through thickness edge crack ($Y_E$) depending on user preference.
#
# $$
# \begin{matrix}
# Y_C & = & 1 &+& 0.256 \left( \frac{a}{w}\right) &-& 1.152 \left( \frac{a}{w}\right)^2 &+& 12.2 \left( \frac{a}{w}\right)^3 &&\\
# Y_E & = & 1.122 &-& 0.231 \left( \frac{a}{w}\right) &+& 10.55 \left( \frac{a}{w}\right)^2 &-& 21.71 \left( \frac{a}{w}\right)^3 &+& 30.38 \left( \frac{a}{w}\right)^4\\
# \end{matrix}
# $$
#
# The algorithm should
# - Ask the use for the values of $a$ and $w$.
# - Ask the user to choose between $Y_C$ and $Y_E$. This could be done with values or characters it is up to you.
# - Print to the screen the geometric value of $Y_C$ and $Y_E$.

# %% [markdown]
# ## Loops
# As already discussed there are two types of loops that are used in Python:
# - The first is where you have an iterable object or know how many iterations you want, called a `for` loop (previous session).
# - The second is a `while` loop where the loop will stop when the pre-set condition is `False`.
#
# Note: for a `while loop, if it does not meet the exit condition, the loop will continue indefinitely. This can result that your Colab session does not response. Try the 'stop' button to break out of this, reload the page or close the tab and start again. Changes are usually automatically saved.
#
#
# ### `for` loops
# The `for` loop is based on vector notation. You provide a starting point, and end point and the increment, and the code will loop through until it ends.

# %%
# this for loop goes between 0 and 100 in steps of 10, excluding 100.
for i in range(0,100,10):
    print(i)

# %% [markdown]
# If you do not specify the start and step, Python will use the default of 0 for start and 1 for step.

# %%
#This for loop goes between two variables in steps of 1
x = 2
y = 5
for i in range(x,y):
    print(i)

# %% [markdown]
# You can use it to step _through_ arrays. Here we use the `for` loop to go through each element in the data array, and square it. Printing the result to the screen.

# %%
data=[2, 5, 6, 9, 7, 8]      # Set up list of data 
for i in range(len(data)):   # Go from 0 to the length of the list excluding 6. 
    output=data[i]**2        # Use i as a index, square the value stored in data
    print('No. {:.0f}: {:.0f} squared is {:.0f}'.format( i+1, data[i], output))

# %% [markdown]
# As the `data` is an iterable object, you can alternatively iterate through each element. If you need an indexer, e.g. store data/results in an array or list, you can produce one with `enumerate()` function, which will count from 0 to the length of your iterable object.

# %%
data=[2, 5, 6, 9, 7, 8]              # Set up vector of data 
for i,element in enumerate(data):    # Iterate through elements of data
    square = element**2              # Square the element
    print('Element {:.0f}: {:.0f} squared is {:.0f}'.format( i+1, element, square))

# %% [markdown]
# ### Task 6
# Write an algorithm that:
# - Asks the user to enter two even values.
# - The algorithm then prints to the screen all the even values between those two values.
# - Keeps a running sum of the values, and prints this at the end.
# - **Hint 1**: Think about the increment needed in the `for` loop.
# - **Hint 2**: You will need to define a variable sum. You can increment sum by adding it to itself e.g. `sum = sum + 1`.
#
# Verification: Entering values of 2 and 10 would display the following.
#
# ```
# 2
# 4
# 6
# 8
# 10
# Sum is 30
# ```

# %% [markdown]
# ### While loops
# The `while` loop asks Python to keep running until a condition is not `True` (`False`).

# %%
a = 0
while (a < 10):
    a = a + 1
    print(a)

# %% [markdown]
# There are two key parts to this.
# - An initialised variable to test against.
# - The variable is updated inside the loop and will execute the code block inside `while` until the condition is not fulfilled anymore (`False`).
#
# ### Loops and breaks
# You can use break commands to exit out of loops. Here we use a `while` loop with a very large condition. If the value you enter is met using an `if` condition, the loop will `break` and jump out of the loop to the end of the code block, printing then the final line.

# %%
a = 0
x = int(input('enter integer value when to stop: '))
while (a < 1e100):
    if (a == x):
        break
    else:
        a = a + 1
print(a)

# %% [markdown]
# ### Task 7
#
# Write an algorithm that:
# - Asks the user to enter the value 4.
# - If 4 is entered it will stop the algorithm.
# - If a different number is entered it will ask you again and keep asking until you enter 4.

# %% [markdown]
# TOUGH CHALLENGE:
#
# - Can you modify your algorithm above such that it asks you to enter in order the sequence of values  4, 8, 15, 16, 23 and 42.
# - If you enter the sequence correctly it prints to the screen "you are not lost" and ends.
#
# ## Task 8  (TOUGH CHALLENGE)
# Use the algorithm you wrote in Task 3 (guess game) and modify so
# - You start with 10 points
# - If you guess correctly, add 5 to your points.
# - If you guess incorrectly, minus 1 off your points total.
# - Once you have 0 points, the algorithm will end.

# %% [markdown]
# ## Task 9: using multiple for loops
#
# Sometimes it is beneficial to use nested `for` loops. This means there are 2 or more `for` loops, one inside the other.
#
# Create a $5 \times 5$ array consisting of zeros and call it A. Use 2 `for` loops and conditional statements to change A so that:
#
# - the entries below the diagonal become 1.
# - the entries above the diagonal become 2.
# - the entries on the diagonal become 3.
#
# $
# A=
# \begin{bmatrix}
# 3&2&2&2&2\\
# 1&3&2&2&2\\
# 1&1&3&2&2\\
# 1&1&1&3&2\\
# 1&1&1&1&3\\
# \end{bmatrix}
# $
