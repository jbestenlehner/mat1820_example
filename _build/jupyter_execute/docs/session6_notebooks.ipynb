# %% [markdown]
# # Tutorial: Reading in and writing out data
#
# This live script will show you how to read in a file of data, how to process, fit the data, and then print the answer to another file.
#
# ## Reading in from a file
# You will need to first download the 'test.txt' file from BlackBoard and upload it to your workspace on Colab ([see overview page](#session6)).
#
# _Numpy_ provides the `np.loadtxt()` function to read in a file. To to so you need to specify at least the following things:
#
# - The name of the file. The file needs to be in your workspace and not locally on your Desktop or Laptop.
# - `delimiter`: This is the symbol that separates the values in the file. This could be a space whitespace including tab (default), a comma ',', '|' or some other symbol. The file separated with commas are more commonly known as a CSV file, or a Comma Separated Variable file.
# - `comments`: The number of comments lines at the start of the file. In this case, if you open the 'test.txt' in word pad of equivalent or `!cat test.txt` in the code cell, you will see 2 rows of text headings. We must make sure Python reads this in as text and not numerical values, but the text is not specifically indicated as a comment with a symbol at the beginning of the line like '#' or '!'. So we have to specify this with the `skiprows` parameter.
# - `skiprows`: If text is not specified as comment, we must make sure Python does not read this in as text. So we have to tell how many lines to skip at the beginning of the row.
# - `unpack`: Default is `False`. All columns are read into a single 2D `np.array()`. If you want to read each column in a separate 1D array, set `unpack` to `True`.
#
# First we need to check the content of the file to see, if there are headers/comments present, what is the delimiter and how the data are structured in the file. To do so you can either open the file with a text editor like word pad or execute the following command in your code cell.

# %%
# !cat  test.txt # prints the content of the file to the screen

# %% [markdown]
# We notice, that there are two lines of comments/header, the delimiter is whitespace and there are two columns of data (x and y).
#
# Note: If you open the file in Excel, Excel will read it into columns and you won't be able to see, what the delimiter is.

# %%
import numpy as np
import matplotlib.pyplot as plt

xy_data = np.loadtxt('test.txt', skiprows = 2)  # Note: delimiter is white space and does not need to be specified (default).
                                                 # header is not indicated by a symbol. So we use skiprows to skip the first 2 lines.
print(xy_data.shape)                             # prints shape
x_data, y_data = np.loadtxt('test.txt', skiprows = 2, unpack=True) # reads each column into a separated array
print(x_data.shape, y_data.shape)

plt.plot(xy_data[:,0], xy_data[:,1],'r-')                           # plot the data
plt.plot(x_data, y_data,'b--')
plt.show()
plt.close()

# %% [markdown]
# ## Task 1
# Download the file 'task1.csv' from blackboard and place it into your current workspace on Colab. The file contains the voltage-current measurements of two samples. Column one is the voltage. Columns 2 and 3 are the current generated in sample 1 and 2 respectively.
# - Look at the file and identify
# - how many text headings it has, and the deliminator that separates the values.
# - Use these to read in the file with `np.loadtxt()`
# - Separate the columns into separated arrays.
# - Plot sample 1 and sample 2 on the same graph.
# - Label the axis including units.

# %% [markdown]
# ## Writing to a file
#
# We use Python's built in functions `open()` and `write()`. To write to a file you have to first open a file with the permission to write to it, given by the option 'w'. You then use `write()` with the string-formatter `.format()` to write to the file (See Tutorial of session 4). Finally close the file.

# %%
fid = open('test_write.txt', 'w')   # open file with write permission. Overwrites any existing file called 'test_write.txt'
fid.write('heading\n')              # Writes some header. Note: '\n' new lines needs to be added to the end of the string.
fid.write('{:.0f} {:.2f}\n'.format(2, np.random.rand())) # formats number values and writes them into a file. 
fid.close()                         # close the file

# %% [markdown]
# - The fid variable stores the open file.
# - The `open()` functions takes in two parameters. The name of the file and the permission to write to the file (See overview page of this session).
# - The `write()` function has one input which is a string. Therefore, we need format our number values to a single string.
# - The first `write()` expression writes a line of text at the top.
# - The second `write()` expression writes two values, the value of 2 followed by a random number, separated by a space.
# - It is really important you then close the file before the algorithm ends. Not all data might be written to the file.
#
# ## Task 2
#
# Using Python's built in functions `open()` and `write()`, write the following code that writes a formatted file.
# - Create an array from 1 to 10 in 9 equal steps. Use this to create another array which adds 5 to each value.
# - Write the resulting values to a file called 'task2.dat'.
# - The contents of the file should looks like this.
#
# ![xy table](../pictures/notebook_session6_task2.png)
#
# Note the columns are labelled as x and y.

# %% [markdown]
# ## Task 3
# Use 'task3.csv' and `np.loadtxt()` as the input for this question.
#
# A vector describing the magnetisation of a material is given in the file 'task3.csv'. It contains the magnetisation moment for the x, y and z directions. The magnitude of the vector should always be less than 1 (i.e. <= 1). Some of the lines however have an error present.
#
# Write a code that:
# - Reads in the file
# - Calculates the vector magnitude of the data given by
#
# $$
# \mathrm{Magnitude} = \sqrt{x^2 + y^2 + z^2}
# $$
#
# - Prints all the correct vectors to a file called task3_correct.dat using `np.savetxt()` (i.e. omitting the incorrect ones).

# %% [markdown]
# ## Task 4
# For this question use the task4.dat file.
#
# A company called SteelyGood makes steel samples with an advertised hardness of 160HV or better. Using a new automated process they have measured the hardness of 50 different samples and recorded it into a data file.
#
# The first column is the sample number, and the second the Vickers hardness.
#
# Write a code that
# - Reads the data in.
# - Prints to the screen the maximum, minimum and average of the data set.
# - Plots a histogram of the data with 10 bins.
# - Prints to the screen any sample whose hardness value is below 160HV.
# - Prints to the screen the percentage of samples that failed to reach 160HV.
# - Prints to a file named "pass.txt" the sample numbers of those samples where the hardness is equal or above 160HV.

# %% [markdown]
# ## Task 5
# Many materials are formed from planes of atoms. To simulate such materials using molecular dynamics we first need to find their correct position.
#
# Write a script that calculates the x, y coordinates for a single plane of atoms. The code requires the number of atoms you would like in the x and y direction (for example in the figure below there are 4 atoms in the x direction and 4 in the y) and then distributes these evenly along the axis assuming they are separated by the atomic radius. So in the example below with a radius of 0.1 the coordinates of the first atom would be (0,0), the second atom would be (0.1,0), the third atom would be (0.2,0) etc.
#
# ![material](../pictures/session6_task5_atoms.png)
#
# It will also require an atomic radius r to be plotted.
#
# Your function will use this information to calculate the positions (x, y coordinates) of the atoms and print these coordinates to a file called 'positions_xy.dat'.
#
# An example of your output should look similar to the following using an atomic radius of 0.125 nm:
#
# Atom_1, x=0.000e+00, y=0.000e+00
#
# Atom_2, x=1.250e-10, y=0.000e+00
#
# Atom_3, x=2.500e-10, y=0.000e+00
#
# Test this to produce the example above, such that it consists of 5 atoms in the x direction and 3 in the y. (A total of 15 atoms).
#
# Use an atomic radius of 0.125 nm. Test your code by plotting it out as points on a scatter graph.

# %% [markdown]
# ## Task 6 (Hard)
# - Can you modify task 5 to be in 3D.
# - Can you then find the positions of a closed packed plane of atoms, first in 2D then in 3D.
